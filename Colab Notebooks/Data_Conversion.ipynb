# %%
# !pip install tabula-py
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 89.1 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import tabula


input_file = 'Cleaned_Ticket_Data.txt'
output_file = 'Cleaned_Ticket_Data.csv'

# For delimited files:
df = pd.read_csv(input_file, sep=',') # Use sep=',' for comma-separated, sep='\s+' for one or more spaces, sep="\t' for tab"
df.to_csv(output_file, index=False)

# For fixed-width files:
# df = pd.read_fwf(input_file, colspecs=[(0, 5), (6, 10)], header=None) # Define column start and end positions
# df.to_csv(output_file, index=False, header=['Column1', 'Column2']) # Add headers if needed
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3-2409790614.py in <cell line: 0>()
#       8
#       9 # For delimited files:
# ---> 10 df = pd.read_csv(input_file, sep=',') # Use sep=',' for comma-separated, sep='\s+' for one or more spaces, sep="\t' for tab"
#      11 df.to_csv(output_file, index=False)
#      12
#
# ...
